# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randn
from numpy import nan as NA
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import platform
from matplotlib import font_manager, rc 
import matplotlib
# '-' 부호가 제대로 표시되게 하는 설정 
matplotlib.rcParams['axes.unicode_minus'] = False
# 운영 체제마다 한글이 보이게 하는 설정 # 윈도우
path = "c:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name() 
rc('font', family=font_name)

# %%
df=pd.read_csv('./data/가구특성별_소득분위별_가구소득_20220624152714.csv')
df
# Out:
#             가구특성별   소득분위별               2017              2017.1  \
# 0           가구특성별   소득분위별  가구소득(전년도) 평균 (만원)  가구소득(전년도) 중앙값 (만원)
# 1              전체      전체               5478                4300
# 2              전체  소득 1분위               1001                   -
# 3              전체  소득 2분위               2556                   -
# 4              전체  소득 3분위               4323                   -
# ..            ...     ...                ...                 ...
# 236  (가구유형) 장애인가구  소득 1분위               1013                   -
# 237  (가구유형) 장애인가구  소득 2분위               2533                   -
# 238  (가구유형) 장애인가구  소득 3분위               4303                   -
# 239  (가구유형) 장애인가구  소득 4분위               6537                   -
# 240  (가구유형) 장애인가구  소득 5분위              12407                   -
#
#                   2018              2018.1               2019  \
# 0    가구소득(전년도) 평균 (만원)  가구소득(전년도) 중앙값 (만원)  가구소득(전년도) 평균 (만원)
# ...

# %%
df=pd.read_csv('./data/test2.csv',names=['a','b','c','d','e'])
df
# Out:
#                 a    b    c    d    e
# 10             20   30   40   50  NaN
# 쥬               피    터    노    트   북
# 호              서     대    학   교   NaN
# 반               갑    습    니   다   NaN
# 데이터사이언스       NaN  NaN  NaN  NaN  NaN
# NaN        부산해운대   NaN  NaN  NaN  NaN
# NaN        안녕하세요   NaN  NaN  NaN  NaN

# %%
df=DataFrame({'b':[4,7,3,2],'a':[4,9,2,5],'c':[5,3,7,9]})
df
# Out:
#    b  a  c
# 0  4  4  5
# 1  7  9  3
# 2  3  2  7
# 3  2  5  9

# %%
df.to_csv('./data/out1.csv')

# %%
# !type.\data\out1.csv
# Out:
# ,b,a,c
# 0,4,4,5
# 1,7,9,3
# 2,3,2,7
# 3,2,5,9

# %%
# !pip install openpyxl
# !pip install xlwt
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 100.0/100.0 kB 5.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openpyxl
import xlwt

# %%
pd.read_excel('./data/tout.xlsx')
# Out:
#    Unnamed: 0  A   B   C   D         E
# 0           0  a   b   c   d  message
# 1           1  1   2   3   4    hello
# 2           2  5   6   7   8    world
# 3           3  9  10  11  12      foo

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\laptop\\Desktop\\DSAC M1'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1day_1.ipynb',
#  '2day_1.ipynb',
#  '2day_2.ipynb',
#  '3day_1.ipynb',
#  '3day_2.ipynb',
#  '4day_1.ipynb',
#  'data',
#  'data.zip',
#  '사진']

# %%
os.mkdir('data2')

# %%
os.rename('data2','new_one')

# %%
os.rmdir('new_one')

# %% [markdown]
# ## json(JavaScript Object Notation):웹 프로그램에서 자주 사용
#
# - 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value))
#
# - "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷
# ### json은 python에서처럼 '으로 하면 안된다. 현재 """로 감싸 문자열로 저장되어 있기 때문에

# %%
#json은 python에서처럼 '으로 하면 안된다. 현재 """로 감싸 문자열로 저장되어 있기 때문에 
obj = """
{
    "name": "Kim",    "places_lived": ["Seoul", "Korea"],
    "pet": null, "siblings": [{"name": "Scott", "age":25, "pet":"Zuko"}]
}
"""

# %%
obj
# Out:
# '\n{\n    "name": "Kim",    "places_lived": ["Seoul", "Korea"],\n    "pet": null, "siblings": [{"name": "Scott", "age":25, "pet":"Zuko"}]\n}\n'

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Kim',
#  'places_lived': ['Seoul', 'Korea'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 25, 'pet': 'Zuko'}]}

# %%
type(result)
# Out:
# dict

# %%
asjson=json.dumps(result)
asjson
# Out:
# '{"name": "Kim", "places_lived": ["Seoul", "Korea"], "pet": null, "siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"}]}'

# %%
type(asjson)
# Out:
# str

# %% [markdown]
# ## 경로 데이터
# https://raw.githubusercontent.com/jpatokal/openflights/master/data/routes.dat

# %%
import csv
f=open('./data/airports.dat',encoding='UTF-8')

for row in csv.reader(f):
    print(row[1])
# Out:
# Goroka Airport
# Madang Airport
# Mount Hagen Kagamuga Airport
# Nadzab Airport
# Port Moresby Jacksons International Airport
# Wewak International Airport
# Narsarsuaq Airport
# Godthaab / Nuuk Airport
# Kangerlussuaq Airport
# Thule Air Base
# Akureyri Airport
# Egilsstaðir Airport
# Hornafjörður Airport
# Húsavík Airport
# Ísafjörður Airport
# Keflavik International Airport
# Patreksfjörður Airport
# Reykjavik Airport
# Siglufjörður Airport
# Vestmannaeyjar Airport
# Sault Ste Marie Airport
# Winnipeg / St. Andrews Airport
# Halifax / CFB Shearwater Heliport
# St. Anthony Airport
# Tofino / Long Beach Airport
# Kugaaruk Airport
# Baie Comeau Airport
# CFB Bagotville
# Baker Lake Airport
# Campbell River Airport
# Brandon Municipal Airport
# Cambridge Bay Airport
# Nanaimo Airport
# Castlegar/West Kootenay Regional Airport
# Miramichi Airport
# Charlo Airport
# Kugluktuk Airport
# Coronation Airport
# Chilliwack Airport
# Clyde River Airport
# Coral Harbour Airport
# ...

# %%
import csv
f=open('./data/airports.dat',encoding='UTF-8')

for row in csv.reader(f):
    if row[3]=='South Korea' :
        print(row[1])
# Out:
# Gwangju Airport
# Jeon Ju Airport (G-703)
# Yeosu Airport
# Sokcho Airport
# Gangneung Airport (K-18)
# Jeju International Airport
# Jinhae Airbase/Airport (G-813/K-10)
# Gimhae International Airport
# Ulsan Airport
# A 511 Airport
# Seoul Air Base (K-16)
# Osan Air Base
# Gimpo International Airport
# Suwon Airport
# Pohang Airport (G-815/K-3)
# Daegu Airport
# Yecheon Airbase
# Incheon International Airport
# Muan International Airport
# Kunsan Air Base
# Mokpo Heliport
# Wonju/Hoengseong Air Base (K-38/K-46)
# Yangyang International Airport
# Sacheon Air Base/Airport
# Cheongju International Airport/Cheongju Air Base (K-59/G-513)
# Jeongseok Airport
# Seosan Air Base
# N 104 Helipad
# Jungwon Air Base/Chungju Airport

# %%
latitudes = {}  #위도
longitudes = {}  #경도
f=open('./data/airports.dat',encoding='UTF-8')

for row in csv.reader(f):
    airport_id=row[0]
    latitudes[airport_id]=float(row[6])
    longitudes[airport_id]=float(row[7])
latitudes
# Out:
# {'1': -6.081689834590001,
#  '2': -5.20707988739,
#  '3': -5.826789855957031,
#  '4': -6.569803,
#  '5': -9.443380355834961,
#  '6': -3.58383011818,
#  '7': 61.1604995728,
#  '8': 64.19090271,
#  '9': 67.0122218992,
#  '10': 76.5311965942,
#  '11': 65.66000366210938,
#  '12': 65.2833023071289,
#  '13': 64.295601,
#  '14': 65.952301,
#  '15': 66.05809783935547,
#  '16': 63.985000610352,
#  '17': 65.555801,
#  '18': 64.1299972534,
#  '19': 66.133301,
#  '20': 63.42430114746094,
#  '21': 46.48500061035156,
#  '22': 50.0564002991,
#  '23': 44.639702,
#  '24': 51.3918991089,
#  '25': 49.079833,
#  '26': 68.534401,
#  '27': 49.13249969482422,
#  '28': 48.33060073852539,
#  '29': 64.29889678960001,
#  '30': 49.950801849365234,
#  '31': 49.91,
#  '32': 69.1081008911,
#  '33': 49.054970224899996,
#  '34': 49.2963981628,
#  '35': 47.007801,
#  '36': 47.990799,
#  '37': 67.816704,
#  '38': 52.0750007629,
#  '39': 49.1528015137,
#  '40': 70.4860992432,
#  '41': 64.1932983398,
# ...

# %%
len(latitudes)
# Out:
# 7698

# %%
# !pip install geopy
# Out:
# ...
#      -------------------------------------- 119.8/119.8 kB 6.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from geopy.distance import great_circle, geodesic

great_cicle((37,127),(38,129))
dist=geodesic((37,127),(38,129))
dist.km
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 3>()
#       1 from geopy.distance import great_circle, geodesic
# ----> 3 great_cicle((37,127),(38,129))
#       4 dist=geodesic((37,127),(38,129))
#       5 dist.km
#
# NameError: name 'great_cicle' is not defined

# %%
f=open('./data/routes.dat',encoding='UTF-8')

for row in csv.reader(f):
    print(row[2])
# Out:
# AER
# ASF
# ASF
# CEK
# CEK
# DME
# DME
# DME
# DME
# EGO
# EGO
# GYD
# KGD
# KZN
# KZN
# KZN
# KZN
# KZN
# KZN
# KZN
# LED
# LED
# LED
# MRV
# NBC
# NBC
# NBC
# NBC
# NJC
# NJC
# NUX
# OVB
# OVB
# SVX
# SVX
# SVX
# SVX
# SVX
# TGK
# UUA
# UUA
# UUA
# BTK
# BTK
# CEK
# HTA
# IKT
# IKT
# IKT
# IKT
# IKT
# IKT
# IKT
# IKT
# KCK
# MJZ
# ODO
# OVB
# OVB
# OVB
# UKX
# ULK
# YKS
# AYP
# CUZ
# CUZ
# HUU
# IQT
# IQT
# LIM
# LIM
# LIM
# LIM
# LIM
# PCL
# PCL
# PCL
# PEM
# TPP
# TPP
# TPP
# ABJ
# ABJ
# ACC
# BKO
# BKO
# BKO
# BOY
# BOY
# COO
# COO
# DKR
# DKR
# LFW
# NIM
# OUA
# OUA
# OUA
# OUA
# OUA
# OUA
# OUA
# OUA
# BOG
# BOG
# CLO
# GYE
# GYE
# GYE
# GYE
# OCC
# SCY
# UIO
# UIO
# UIO
# BDS
# BOD
# BRS
# GVA
# LCA
# LPA
# RMF
# TFS
# ZRH
# ZRH
# ZRH
# ZRH
# ZRH
# ZRH
# AJR
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# ARN
# GEV
# GEV
# HAD
# HAD
# HAD
# HMV
# JKG
# JKG
# KOK
# KRF
# KRF
# KSD
# LYC
# LYC
# MHQ
# MHQ
# OER
# OSL
# POR
# POR
# TKU
# TRF
# VBY
# ...

# %%
distances = []
f = open("./data/routes.dat")
for row in csv.reader(f):
    source_airport = row[3]
    dest_airport = row[5]
    if source_airport in latitudes and dest_airport in latitudes:
        source_lat = latitudes[source_airport]
        source_long = longitudes[source_airport]
        dest_lat = latitudes[dest_airport]
        dest_long = longitudes[dest_airport]
        distances.append(great_circle((source_lat,source_long),(dest_lat,dest_long)).km)
distances
# Out:
# [1506.8277330777387,
#  1040.4397895432182,
#  448.16554181018654,
#  770.5095886094415,
#  1338.6333576053873,
#  715.6503614468733,
#  892.3840483798505,
#  951.4335423246899,
#  1171.8831507434213,
#  1008.2545343994207,
#  1685.4289052915774,
#  1171.883150743421,
#  1506.8277330777385,
#  1040.4397895432187,
#  770.5095886094417,
#  715.6503614468731,
#  1008.2545343994209,
#  1216.8462864592682,
#  723.5242256058544,
#  1216.8462864592682,
#  1372.8883537724205,
#  1464.0590032741716,
#  448.16554181018637,
#  892.3840483798502,
#  1685.428905291577,
#  1372.8883537724205,
#  554.7041432647163,
#  1012.6041440304277,
#  1557.1740217580923,
#  1324.6136239685436,
#  1338.6333576053873,
#  1370.2991943842778,
#  723.5242256058546,
#  554.7041432647164,
#  1012.6041440304275,
#  1324.6136239685436,
#  1370.2991943842778,
#  951.4335423246899,
#  1464.0590032741718,
#  1557.1740217580925,
#  488.3403114474664,
#  1199.360850196032,
#  1338.6333576053873,
#  608.6439208266945,
# ...

# %%
plt.hist(distances,100,facecolor='b')
plt.xlabel('Distances (km)')
plt.ylabel('Number of flights')
# Out:
# Text(0, 0.5, 'Number of flights')

# %%
from datetime import datetime
now=datetime.now()
print(now)
# Out:
# 2023-01-05 11:52:27.908148

# %%
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 2023
# 1
# 5
# 11
# 52
# 27

# %%
now=datetime.now()
print(str(now.month)+'/'+str(now.day)+'/'+str(now.year))
print(str(now.hour)+'/'+str(now.minute)+'/'+str(now.second))
# Out:
# 1/5/2023
# 11/56/29

# %% [markdown]
# # 영업일 캘린더 (KRX)
#
# * 한국거래소 홈페이지에서 휴장일을 xls로 받을 수 있다
# * 휴장일 데이터로 부터 개장일(market days)를 생성
# * 해외 시장(CME, EUREX)등은  pandas-market-calendars를 활용
#
# <img width="320" src="http://i.imgur.com/ClIQff8.jpg" >
#
# #### 2017 http://fb.com/financedata , http://financedata.github.io
# <!-- TEASER_END -->

# %% [markdown]
# 한국거래소, CME, EUREX 캘린더를 년도별로 제공하고 있으며, '다운로드'를 누르면 엑셀(data.xls)파일로 다운로드 할 수 있다.
#
# 다운로드한 파일(data.xls)을 아래와 같이 공유파일 링크로 만들었다.
#
# - 데이터 https://goo.gl/JGse1n

# %%
df_days=pd.read_excel('https://goo.gl/JGse1n')
df_days
# Out:
#        일자 및 요일    요일구분          비고
# 0   2019-01-01  화요일             신정
# 1   2019-02-04  월요일             설날
# 2   2019-02-05  화요일             설날
# 3   2019-02-06  수요일             설날
# 4   2019-03-01  금요일            삼일절
# 5   2019-05-01  수요일          근로자의날
# 6   2019-05-06  월요일     어린이날(대체휴일)
# 7   2019-06-06  목요일            현충일
# 8   2019-08-15  목요일            광복절
# 9   2019-09-12  목요일             추석
# 10  2019-09-13  금요일             추석
# 11  2019-10-03  목요일            개천절
# 12  2019-10-09  수요일            한글날
# 13  2019-12-25  수요일            성탄절
# 14  2019-12-31  화요일          연말휴장일

# %%
df_days=pd.read_excel('data\stock_holodays.xls')
df_days
# Out:
#        일자 및 요일    요일구분          비고
# 0   2019-01-01  화요일             신정
# 1   2019-02-04  월요일             설날
# 2   2019-02-05  화요일             설날
# 3   2019-02-06  수요일             설날
# 4   2019-03-01  금요일            삼일절
# 5   2019-05-01  수요일          근로자의날
# 6   2019-05-06  월요일     어린이날(대체휴일)
# 7   2019-06-06  목요일            현충일
# 8   2019-08-15  목요일            광복절
# 9   2019-09-12  목요일             추석
# 10  2019-09-13  금요일             추석
# 11  2019-10-03  목요일            개천절
# 12  2019-10-09  수요일            한글날
# 13  2019-12-25  수요일            성탄절
# 14  2019-12-31  화요일          연말휴장일

# %%
hdays=df_days['일자 및 요일'].str.extract('(\d{4}-\d{2}-\d{2})',expand=False)
hdays
# Out:
# 0     2019-01-01
# 1     2019-02-04
# 2     2019-02-05
# 3     2019-02-06
# 4     2019-03-01
# 5     2019-05-01
# 6     2019-05-06
# 7     2019-06-06
# 8     2019-08-15
# 9     2019-09-12
# 10    2019-09-13
# 11    2019-10-03
# 12    2019-10-09
# 13    2019-12-25
# 14    2019-12-31
# Name: 일자 및 요일, dtype: object

# %%
hdays1=pd.to_datetime(hdays)
hdays1.name='날짜'
hdays1
# Out:
# 0    2019-01-01
# 1    2019-02-04
# 2    2019-02-05
# 3    2019-02-06
# 4    2019-03-01
# 5    2019-05-01
# 6    2019-05-06
# 7    2019-06-06
# 8    2019-08-15
# 9    2019-09-12
# 10   2019-09-13
# 11   2019-10-03
# 12   2019-10-09
# 13   2019-12-25
# 14   2019-12-31
# Name: 날짜, dtype: datetime64[ns]

# %% [markdown]
# ### 개장일(market day)
# 2019년 중에 개장일(market day)목록을 만들어 보자.
#
# 우선 pandas.date_range() 함수를 사용하여 1월 1일~ 12월 31까지 날짜를 생성한다. (365일)
