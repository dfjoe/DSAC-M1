# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randn
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import platform
from matplotlib import font_manager, rc 
import matplotlib
# '-' 부호가 제대로 표시되게 하는 설정 
matplotlib.rcParams['axes.unicode_minus'] = False
# 운영 체제마다 한글이 보이게 하는 설정 # 윈도우
path = "c:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name() 
rc('font', family=font_name)

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

# %%
ax1.hist(np.random.randn(200),bins=10,color='r',width=0.3)
ax2.scatter(np.arange(30),np.arange(30) + 3*np.random.randn(30))
ax3.plot(np.arange(10),np.random.randn(10))
fig

#코드를 2번 이상 실행하면 계속 겹쳐서 그린다. 
#이를 해결하기 위해 위쪽 빈 분할 코드 실행 후 다시 실행.

# %%
axes=plt.subplots(2,3)
axes
# Out:
# (<Figure size 432x288 with 6 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=None, hspace=None)

# subplot 간의 간격을 조정하는 함수 _adjust()
# wspace, hspace: subplot 간의 높이 너비

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)

for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5) 

plt.subplots_adjust(wspace=0,hspace=0)

# sharex : 모든 그래프에서 x 값의 범위가 동일한지 여부 
# sharey : 모든 그래프에서 y 값의 범위가 동일한지 여부 
# alpha는 투명도를 의미합니다. 0.0에서 1.0 사이의 값

# %%
plt.plot(randn(30),'ko--')

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

# %%
# 누적 합(뭐라뭐라 영어 였음)

ax1.plot(randn(1000).cumsum(),'k')
ax2.plot(randn(1000).cumsum(),'b--')
ax3.plot(randn(1000).cumsum(),'r^')
ax4.plot(randn(1000).cumsum(),'go')
fig

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'b--',label='two')
ax.plot(randn(1000).cumsum(),'r^',label='three')
ax.plot(randn(1000).cumsum(),'go',label='four')

ax.legend(loc='best')

# %%
fig = plt.figure()
figm,axes=plt.subplots(2,1)

data=Series(np.random.rand(16),index=list('abcdefghijklmnop'))

data.plot(kind='bar',ax=axes[0],color='b',alpha=0.9)
data.plot(kind='barh',ax=axes[1],color='r',alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.5, 0.2, color = "g", alpha = 0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color = "b", alpha = 0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color = "r", alpha = 0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
df= DataFrame(np.random.rand(6,4),
             index=['one','two','three','four','five','six'],
             columns=pd.Index(['a','b','c','d'],
             name='genus'))
df
# Out:
# genus         a         b         c         d
# one    0.658860  0.439904  0.285248  0.199934
# two    0.328889  0.617512  0.172169  0.865601
# three  0.352299  0.569782  0.401562  0.639226
# four   0.851737  0.712829  0.247260  0.661006
# five   0.044656  0.667258  0.385933  0.013178
# six    0.687723  0.128252  0.233762  0.293873

# %%
df.plot(kind='kde')  
#kind: 그래프 종류  'line','bar','barh','kde'(kernel density estimation - 히스토그램으로부터 확률밀도함수 추정)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot(kind='bar',stacked=True)  #stacked는  그래프를 합치는지 마는지
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh',stacked=False)
# Out:
# <AxesSubplot:>

# %%
np.random.seed(2)  #만일 seed 값이 같다면 항상 같은 난수를 얻게된다.
f=np.random.normal(0,1,size=10)

f
# Out:
# array([-0.41675785, -0.05626683, -2.1361961 ,  1.64027081, -1.79343559,
#        -0.84174737,  0.50288142, -1.24528809, -1.05795222, -0.90900761])

# %%
np.random.seed(2) 
comp1=np.random.normal(0,1,size=200)
comp2=np.random.normal(10,2,size=200)

values=Series(np.concatenate([comp1,comp2]))
#concat(1,2): 1번째 문자열에 두번째 문자열을 합치는 함수와 동일

values.hist(bins=100,alpha=0.3,color='k',density=True)
values.plot(kind='kde',style='k--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 4.3데이터프레임 연습 p.109

# %%
obj=Series(range(4),index=['d','a','b','c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
obj1=obj.sort_index()
obj1
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame=DataFrame(np.arange(8).reshape((2,4)),
                index=['three','one'],columns=['d','a','b','c'])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis=1) #열기준 정렬
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1,ascending=False) #열기준 내림 정렬
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
frame=DataFrame({'b':[4,7,3,2],'a':[4,9,2,5],'c':[5,3,7,8]})
frame
# Out:
#    b  a  c
# 0  4  4  5
# 1  7  9  3
# 2  3  2  7
# 3  2  5  8

# %%
frame.sort_values(by='b') #칼럼b를 기준으로 오름차순 정렬
# Out:
#    b  a  c
# 3  2  5  8
# 2  3  2  7
# 0  4  4  5
# 1  7  9  3

# %%
frame.sort_values(by='a') #칼럼a를 기준으로 오름차순 정렬
# Out:
#    b  a  c
# 2  3  2  7
# 0  4  4  5
# 3  2  5  8
# 1  7  9  3

# %%
obj=Series([100,23,55,44,22,99,33])
obj
# Out:
# 0    100
# 1     23
# 2     55
# 3     44
# 4     22
# 5     99
# 6     33
# dtype: int64

# %%
obj.rank()
# Out:
# 0    7.0
# 1    2.0
# 2    5.0
# 3    4.0
# 4    1.0
# 5    6.0
# 6    3.0
# dtype: float64

# %%
obj.rank(ascending=False)
# Out:
# 0    1.0
# 1    6.0
# 2    3.0
# 3    4.0
# 4    7.0
# 5    2.0
# 6    5.0
# dtype: float64

# %%
obj=Series([100,23,100,44,22,99,33])
obj.rank(ascending=False,method='first')

#동일한 값이 존재할 경우 먼저 나타나는 값에 높은 순위 부여  method='first'
# Out:
# 0    1.0
# 1    6.0
# 2    2.0
# 3    4.0
# 4    7.0
# 5    3.0
# 6    5.0
# dtype: float64

# %%
obj.rank(method='first')
# Out:
# 0    6.0
# 1    2.0
# 2    7.0
# 3    4.0
# 4    1.0
# 5    5.0
# 6    3.0
# dtype: float64

# %%
frame=DataFrame({'b':[4,7,3,2],'a':[4,9,2,5],'c':[5,3,7,8]})
frame
# Out:
#    b  a  c
# 0  4  4  5
# 1  7  9  3
# 2  3  2  7
# 3  2  5  8

# %%
frame.rank()
# Out:
#      b    a    c
# 0  3.0  2.0  2.0
# 1  4.0  4.0  1.0
# 2  2.0  1.0  3.0
# 3  1.0  3.0  4.0

# %%
frame.rank(axis=1) #행기준 순위
# Out:
#      b    a    c
# 0  1.5  1.5  3.0
# 1  2.0  3.0  1.0
# 2  2.0  1.0  3.0
# 3  1.0  2.0  3.0

# %%
frame=DataFrame({'b':[4,7,3,2],'a':[4,9,2,5],'c':[5,3,7,np.nan]}) #nan is not a number
frame
# Out:
#    b  a    c
# 0  4  4  5.0
# 1  7  9  3.0
# 2  3  2  7.0
# 3  2  5  NaN

# %%
frame.sum() #nan 이 있는경우 제외하고 계산
# Out:
# b    16.0
# a    20.0
# c    15.0
# dtype: float64

# %%
frame.mean()
# Out:
# b    4.0
# a    5.0
# c    5.0
# dtype: float64

# %%
frame.idxmax() #최대값이 있는 위치 반환
# Out:
# b    1
# a    1
# c    2
# dtype: int64

# %%
frame.idxmin() #최소값이 있는 위치 반환
# Out:
# b    3
# a    2
# c    1
# dtype: int64

# %%
obj=Series(['c','a','d','a','a','b','b','c','c'])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
uni=obj.unique()
uni
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts()
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
mask=obj.isin(['b','c'])  #b 와 c 의 위치 찾기
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
obj[obj.isin(['b','c'])]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
frame = DataFrame({'X':['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'], 
                  'Y':['f', 'g', 'd', 'g', 'h', 'e', 'd', 'h', 'f'],
                   'Z':['a', 'e', 'd', 'g', 'd', 'e', 'q', 'b', 'c']})
frame
# Out:
#    X  Y  Z
# 0  c  f  a
# 1  a  g  e
# 2  d  d  d
# 3  a  g  g
# 4  a  h  d
# 5  b  e  e
# 6  b  d  q
# 7  c  h  b
# 8  c  f  c

# %%
frame.apply(lambda s :s.value_counts())
# Out:
#      X    Y    Z
# a  3.0  NaN  1.0
# b  2.0  NaN  1.0
# c  3.0  NaN  1.0
# d  1.0  2.0  2.0
# e  NaN  1.0  2.0
# f  NaN  2.0  NaN
# g  NaN  2.0  1.0
# h  NaN  2.0  NaN
# q  NaN  NaN  1.0

# %%
result=frame.apply(pd.value_counts)
result
# Out:
#      X    Y    Z
# a  3.0  NaN  1.0
# b  2.0  NaN  1.0
# c  3.0  NaN  1.0
# d  1.0  2.0  2.0
# e  NaN  1.0  2.0
# f  NaN  2.0  NaN
# g  NaN  2.0  1.0
# h  NaN  2.0  NaN
# q  NaN  NaN  1.0

# %%
result=frame.apply(pd.value_counts).fillna(0) #change nan to 0
result
# Out:
#      X    Y    Z
# a  3.0  0.0  1.0
# b  2.0  0.0  1.0
# c  3.0  0.0  1.0
# d  1.0  2.0  2.0
# e  0.0  1.0  2.0
# f  0.0  2.0  0.0
# g  0.0  2.0  1.0
# h  0.0  2.0  0.0
# q  0.0  0.0  1.0

# %% [markdown]
# # 결측치 처리
# ## 1. 결측치 해당 행을 삭제 dropna()
# ## 2. 결측치 값을 모두 같은 값으로 채우기 fillna(0)  - 0으로 채우기
# ## 3. 결측치 값을 평균값으로 채우기

# %%
from numpy import nan as NA

data=Series([1,NA, 3.5,NA,7])
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = DataFrame([[NA, 6.5, 3.], [NA, NA, NA],
                  [NA, NA, NA], [NA, 6.5, 3.]])

data
# Out:
#     0    1    2
# 0 NaN  6.5  3.0
# 1 NaN  NaN  NaN
# 2 NaN  NaN  NaN
# 3 NaN  6.5  3.0

# %%
cleaned=data.dropna()
cleaned
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %% [markdown]
# # 파일 다루기
# - 텍스트 파일 다운로드
# - http://opentechschool.github.io/python-data-intro/files/radishsurvey.txt
